# %%
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization, Add, MaxPooling2D, Flatten, Dense, Softmax, Activation, GlobalAveragePooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import Adam, Nadam, SGD
import numpy as np
import h5py

# %%
tf.__version__
tf.test.is_gpu_available()
# Out:
# True

# %%
def dataGenerator(start_index, stop_index):
    def generator():
        indexes = shuff[start_index : stop_index]
        for i in indexes:
            x = np.array(hdf5['Xs'][i])
            y = np.array(hdf5['Ys'][i])
            yield x, y
    return generator

# %%
hdf5 = h5py.File('./hdf5/kyu_dataset_cor.hdf5','r')
batch_size = 64
dataset_size = hdf5['Xs'].shape[0]
val_start = 0.8
val_stop = 1.0

train_steps = int(dataset_size * (val_start)/batch_size)
val_steps = int(dataset_size * (val_stop - val_start)/batch_size)
print(f"train_steps: {train_steps}, val_steps: {val_steps}")
shuff = np.arange(dataset_size)
np.random.shuffle(shuff)

data_gen = dataGenerator(start_index = 0, stop_index = int(dataset_size * val_start)) # 80% of the complete dataset
dataset = tf.data.Dataset.from_generator(data_gen, 
                                         output_types=(tf.dtypes.float32, tf.dtypes.int32),
                                         output_shapes=(tf.TensorShape((19,19,19)),tf.TensorShape((1))))
dataset = dataset.batch(batch_size, drop_remainder=True)
dataset = dataset.prefetch(tf.data.AUTOTUNE)

data_gen_valid = dataGenerator(start_index=int(dataset_size * val_start), # 20% of the complete dataset
                               stop_index=int(dataset_size * val_stop))
dataset_valid = tf.data.Dataset.from_generator(data_gen_valid, 
                                         output_types=(tf.dtypes.float32, tf.dtypes.int32),
                                         output_shapes=(tf.TensorShape((19,19,19)),tf.TensorShape((1))))
dataset_valid = dataset_valid.batch(batch_size, drop_remainder=True)
dataset_valid = dataset_valid.prefetch(tf.data.AUTOTUNE)
# Out:
# train_steps: 169592, val_steps: 42398

# %%
# resnet50
def block1(x, filters, kernel_size=3, stride=1, conv_shortcut=False):
    bn_axis=3
    preact = Activation("relu")(x)
    if conv_shortcut:
        shortcut = Conv2D(4 * filters, 1, strides=stride)(preact)
    else:
        shortcut = x
    
    x = Conv2D(filters, 1, strides=1, use_bias=False)(preact)
    x = Activation("relu")(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)))(x)
    x = Conv2D(
        filters,
        kernel_size,
        strides=stride,
        use_bias=False
    )(x)
    x = Activation("relu")(x)
    x = Conv2D(4 * filters, 1)(x)
    x = Add()([shortcut, x])
    return x

def ResNet50(include_top=True,
             input_tensor=None,
             input_shape=None,
             pooling=False):
    inputs = Input(shape = input_shape)
    x = block1(inputs, 256, conv_shortcut=True)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    
    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dense(361, activation='softmax', name='fc1000')(x)

    model = Model(inputs, x, name='resnet50')
    return model

model = ResNet50(include_top=True,
                 input_tensor=None,
                 input_shape=(19, 19, 19),
                 pooling=False)
opt = Nadam(learning_rate = 0.0001)
model.compile(optimizer = opt,
              loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 19, 19, 19)  0           []
#                                 ]
#
#  activation_87 (Activation)     (None, 19, 19, 19)   0           ['input_2[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 19, 19, 256)  4864        ['activation_87[0][0]']
#
#  activation_88 (Activation)     (None, 19, 19, 256)  0           ['conv2d_89[0][0]']
#
#  zero_padding2d_29 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_88[0][0]']
#  2D)
#
#  conv2d_90 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_29[0][0]']
#
#  activation_89 (Activation)     (None, 19, 19, 256)  0           ['conv2d_90[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 19, 19, 1024  20480       ['activation_87[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_89[0][0]']
#                                 )
#
#  add_29 (Add)                   (None, 19, 19, 1024  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_91[0][0]']
#
#  activation_90 (Activation)     (None, 19, 19, 1024  0           ['add_29[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_90[0][0]']
#
#  activation_91 (Activation)     (None, 19, 19, 256)  0           ['conv2d_92[0][0]']
#
#  zero_padding2d_30 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_91[0][0]']
#  2D)
#
#  conv2d_93 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_30[0][0]']
#
#  activation_92 (Activation)     (None, 19, 19, 256)  0           ['conv2d_93[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_92[0][0]']
#                                 )
#
#  add_30 (Add)                   (None, 19, 19, 1024  0           ['add_29[0][0]',
#                                 )                                 'conv2d_94[0][0]']
#
#  activation_93 (Activation)     (None, 19, 19, 1024  0           ['add_30[0][0]']
#                                 )
#
#  conv2d_95 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_93[0][0]']
#
#  activation_94 (Activation)     (None, 19, 19, 256)  0           ['conv2d_95[0][0]']
#
#  zero_padding2d_31 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_94[0][0]']
#  2D)
#
#  conv2d_96 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_31[0][0]']
#
#  activation_95 (Activation)     (None, 19, 19, 256)  0           ['conv2d_96[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_95[0][0]']
#                                 )
#
#  add_31 (Add)                   (None, 19, 19, 1024  0           ['add_30[0][0]',
#                                 )                                 'conv2d_97[0][0]']
#
#  activation_96 (Activation)     (None, 19, 19, 1024  0           ['add_31[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_96[0][0]']
#
#  activation_97 (Activation)     (None, 19, 19, 256)  0           ['conv2d_98[0][0]']
#
#  zero_padding2d_32 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_97[0][0]']
#  2D)
#
#  conv2d_99 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_32[0][0]']
#
#  activation_98 (Activation)     (None, 19, 19, 256)  0           ['conv2d_99[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_98[0][0]']
#                                 )
#
#  add_32 (Add)                   (None, 19, 19, 1024  0           ['add_31[0][0]',
#                                 )                                 'conv2d_100[0][0]']
#
#  activation_99 (Activation)     (None, 19, 19, 1024  0           ['add_32[0][0]']
#                                 )
#
#  conv2d_101 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_99[0][0]']
#
#  activation_100 (Activation)    (None, 19, 19, 256)  0           ['conv2d_101[0][0]']
#
#  zero_padding2d_33 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_100[0][0]']
#  2D)
#
#  conv2d_102 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_33[0][0]']
#
#  activation_101 (Activation)    (None, 19, 19, 256)  0           ['conv2d_102[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_101[0][0]']
#                                 )
#
#  add_33 (Add)                   (None, 19, 19, 1024  0           ['add_32[0][0]',
#                                 )                                 'conv2d_103[0][0]']
#
#  activation_102 (Activation)    (None, 19, 19, 1024  0           ['add_33[0][0]']
#                                 )
#
#  conv2d_104 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_102[0][0]']
#
#  activation_103 (Activation)    (None, 19, 19, 256)  0           ['conv2d_104[0][0]']
#
#  zero_padding2d_34 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_103[0][0]']
#  2D)
#
#  conv2d_105 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_34[0][0]']
#
#  activation_104 (Activation)    (None, 19, 19, 256)  0           ['conv2d_105[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_104[0][0]']
#                                 )
#
#  add_34 (Add)                   (None, 19, 19, 1024  0           ['add_33[0][0]',
#                                 )                                 'conv2d_106[0][0]']
#
#  activation_105 (Activation)    (None, 19, 19, 1024  0           ['add_34[0][0]']
#                                 )
#
#  conv2d_107 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_105[0][0]']
#
#  activation_106 (Activation)    (None, 19, 19, 256)  0           ['conv2d_107[0][0]']
#
#  zero_padding2d_35 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_106[0][0]']
#  2D)
#
#  conv2d_108 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_35[0][0]']
#
#  activation_107 (Activation)    (None, 19, 19, 256)  0           ['conv2d_108[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_107[0][0]']
#                                 )
#
#  add_35 (Add)                   (None, 19, 19, 1024  0           ['add_34[0][0]',
#                                 )                                 'conv2d_109[0][0]']
#
#  activation_108 (Activation)    (None, 19, 19, 1024  0           ['add_35[0][0]']
#                                 )
#
#  conv2d_110 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_108[0][0]']
#
#  activation_109 (Activation)    (None, 19, 19, 256)  0           ['conv2d_110[0][0]']
#
#  zero_padding2d_36 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_109[0][0]']
#  2D)
#
#  conv2d_111 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_36[0][0]']
#
#  activation_110 (Activation)    (None, 19, 19, 256)  0           ['conv2d_111[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_110[0][0]']
#                                 )
#
#  add_36 (Add)                   (None, 19, 19, 1024  0           ['add_35[0][0]',
#                                 )                                 'conv2d_112[0][0]']
#
#  activation_111 (Activation)    (None, 19, 19, 1024  0           ['add_36[0][0]']
#                                 )
#
#  conv2d_113 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_111[0][0]']
#
#  activation_112 (Activation)    (None, 19, 19, 256)  0           ['conv2d_113[0][0]']
#
#  zero_padding2d_37 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_112[0][0]']
#  2D)
#
#  conv2d_114 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_37[0][0]']
#
#  activation_113 (Activation)    (None, 19, 19, 256)  0           ['conv2d_114[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_113[0][0]']
#                                 )
#
#  add_37 (Add)                   (None, 19, 19, 1024  0           ['add_36[0][0]',
#                                 )                                 'conv2d_115[0][0]']
#
#  activation_114 (Activation)    (None, 19, 19, 1024  0           ['add_37[0][0]']
#                                 )
#
#  conv2d_116 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_114[0][0]']
#
#  activation_115 (Activation)    (None, 19, 19, 256)  0           ['conv2d_116[0][0]']
#
#  zero_padding2d_38 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_115[0][0]']
#  2D)
#
#  conv2d_117 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_38[0][0]']
#
#  activation_116 (Activation)    (None, 19, 19, 256)  0           ['conv2d_117[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_116[0][0]']
#                                 )
#
#  add_38 (Add)                   (None, 19, 19, 1024  0           ['add_37[0][0]',
#                                 )                                 'conv2d_118[0][0]']
#
#  activation_117 (Activation)    (None, 19, 19, 1024  0           ['add_38[0][0]']
#                                 )
#
#  conv2d_119 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_117[0][0]']
#
#  activation_118 (Activation)    (None, 19, 19, 256)  0           ['conv2d_119[0][0]']
#
#  zero_padding2d_39 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_118[0][0]']
#  2D)
#
#  conv2d_120 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_39[0][0]']
#
#  activation_119 (Activation)    (None, 19, 19, 256)  0           ['conv2d_120[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_119[0][0]']
#                                 )
#
#  add_39 (Add)                   (None, 19, 19, 1024  0           ['add_38[0][0]',
#                                 )                                 'conv2d_121[0][0]']
#
#  activation_120 (Activation)    (None, 19, 19, 1024  0           ['add_39[0][0]']
#                                 )
#
#  conv2d_122 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_120[0][0]']
#
#  activation_121 (Activation)    (None, 19, 19, 256)  0           ['conv2d_122[0][0]']
#
#  zero_padding2d_40 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_121[0][0]']
#  2D)
#
#  conv2d_123 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_40[0][0]']
#
#  activation_122 (Activation)    (None, 19, 19, 256)  0           ['conv2d_123[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_122[0][0]']
#                                 )
#
#  add_40 (Add)                   (None, 19, 19, 1024  0           ['add_39[0][0]',
#                                 )                                 'conv2d_124[0][0]']
#
#  activation_123 (Activation)    (None, 19, 19, 1024  0           ['add_40[0][0]']
#                                 )
#
#  conv2d_125 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_123[0][0]']
#
#  activation_124 (Activation)    (None, 19, 19, 256)  0           ['conv2d_125[0][0]']
#
#  zero_padding2d_41 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_124[0][0]']
#  2D)
#
#  conv2d_126 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_41[0][0]']
#
#  activation_125 (Activation)    (None, 19, 19, 256)  0           ['conv2d_126[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_125[0][0]']
#                                 )
#
#  add_41 (Add)                   (None, 19, 19, 1024  0           ['add_40[0][0]',
#                                 )                                 'conv2d_127[0][0]']
#
#  activation_126 (Activation)    (None, 19, 19, 1024  0           ['add_41[0][0]']
#                                 )
#
#  conv2d_128 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_126[0][0]']
#
#  activation_127 (Activation)    (None, 19, 19, 256)  0           ['conv2d_128[0][0]']
#
#  zero_padding2d_42 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_127[0][0]']
#  2D)
#
#  conv2d_129 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_42[0][0]']
#
#  activation_128 (Activation)    (None, 19, 19, 256)  0           ['conv2d_129[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_128[0][0]']
#                                 )
#
#  add_42 (Add)                   (None, 19, 19, 1024  0           ['add_41[0][0]',
#                                 )                                 'conv2d_130[0][0]']
#
#  activation_129 (Activation)    (None, 19, 19, 1024  0           ['add_42[0][0]']
#                                 )
#
#  conv2d_131 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_129[0][0]']
#
#  activation_130 (Activation)    (None, 19, 19, 256)  0           ['conv2d_131[0][0]']
#
#  zero_padding2d_43 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_130[0][0]']
#  2D)
#
#  conv2d_132 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_43[0][0]']
#
#  activation_131 (Activation)    (None, 19, 19, 256)  0           ['conv2d_132[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_131[0][0]']
#                                 )
#
#  add_43 (Add)                   (None, 19, 19, 1024  0           ['add_42[0][0]',
#                                 )                                 'conv2d_133[0][0]']
#
#  activation_132 (Activation)    (None, 19, 19, 1024  0           ['add_43[0][0]']
#                                 )
#
#  conv2d_134 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_132[0][0]']
#
#  activation_133 (Activation)    (None, 19, 19, 256)  0           ['conv2d_134[0][0]']
#
#  zero_padding2d_44 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_133[0][0]']
#  2D)
#
#  conv2d_135 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_44[0][0]']
#
#  activation_134 (Activation)    (None, 19, 19, 256)  0           ['conv2d_135[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_134[0][0]']
#                                 )
#
#  add_44 (Add)                   (None, 19, 19, 1024  0           ['add_43[0][0]',
#                                 )                                 'conv2d_136[0][0]']
#
#  activation_135 (Activation)    (None, 19, 19, 1024  0           ['add_44[0][0]']
#                                 )
#
#  conv2d_137 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_135[0][0]']
#
#  activation_136 (Activation)    (None, 19, 19, 256)  0           ['conv2d_137[0][0]']
#
#  zero_padding2d_45 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_136[0][0]']
#  2D)
#
#  conv2d_138 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_45[0][0]']
#
#  activation_137 (Activation)    (None, 19, 19, 256)  0           ['conv2d_138[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_137[0][0]']
#                                 )
#
#  add_45 (Add)                   (None, 19, 19, 1024  0           ['add_44[0][0]',
#                                 )                                 'conv2d_139[0][0]']
#
#  activation_138 (Activation)    (None, 19, 19, 1024  0           ['add_45[0][0]']
#                                 )
#
#  conv2d_140 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_138[0][0]']
#
#  activation_139 (Activation)    (None, 19, 19, 256)  0           ['conv2d_140[0][0]']
#
#  zero_padding2d_46 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_139[0][0]']
#  2D)
#
#  conv2d_141 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_46[0][0]']
#
#  activation_140 (Activation)    (None, 19, 19, 256)  0           ['conv2d_141[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_140[0][0]']
#                                 )
#
#  add_46 (Add)                   (None, 19, 19, 1024  0           ['add_45[0][0]',
#                                 )                                 'conv2d_142[0][0]']
#
#  activation_141 (Activation)    (None, 19, 19, 1024  0           ['add_46[0][0]']
#                                 )
#
#  conv2d_143 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_141[0][0]']
#
#  activation_142 (Activation)    (None, 19, 19, 256)  0           ['conv2d_143[0][0]']
#
#  zero_padding2d_47 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_142[0][0]']
#  2D)
#
#  conv2d_144 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_47[0][0]']
#
#  activation_143 (Activation)    (None, 19, 19, 256)  0           ['conv2d_144[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_143[0][0]']
#                                 )
#
#  add_47 (Add)                   (None, 19, 19, 1024  0           ['add_46[0][0]',
#                                 )                                 'conv2d_145[0][0]']
#
#  activation_144 (Activation)    (None, 19, 19, 1024  0           ['add_47[0][0]']
#                                 )
#
#  conv2d_146 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_144[0][0]']
#
#  activation_145 (Activation)    (None, 19, 19, 256)  0           ['conv2d_146[0][0]']
#
#  zero_padding2d_48 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_145[0][0]']
#  2D)
#
#  conv2d_147 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_48[0][0]']
#
#  activation_146 (Activation)    (None, 19, 19, 256)  0           ['conv2d_147[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_146[0][0]']
#                                 )
#
#  add_48 (Add)                   (None, 19, 19, 1024  0           ['add_47[0][0]',
#                                 )                                 'conv2d_148[0][0]']
#
#  activation_147 (Activation)    (None, 19, 19, 1024  0           ['add_48[0][0]']
#                                 )
#
#  conv2d_149 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_147[0][0]']
#
#  activation_148 (Activation)    (None, 19, 19, 256)  0           ['conv2d_149[0][0]']
#  zero_padding2d_49 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_148[0][0]']
#  2D)
#
#  conv2d_150 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_49[0][0]']
#
#  activation_149 (Activation)    (None, 19, 19, 256)  0           ['conv2d_150[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_149[0][0]']
#                                 )
#
#  add_49 (Add)                   (None, 19, 19, 1024  0           ['add_48[0][0]',
#                                 )                                 'conv2d_151[0][0]']
#
#  activation_150 (Activation)    (None, 19, 19, 1024  0           ['add_49[0][0]']
#                                 )
#
#  conv2d_152 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_150[0][0]']
#
#  activation_151 (Activation)    (None, 19, 19, 256)  0           ['conv2d_152[0][0]']
#
#  zero_padding2d_50 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_151[0][0]']
#  2D)
#
#  conv2d_153 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_50[0][0]']
#
#  activation_152 (Activation)    (None, 19, 19, 256)  0           ['conv2d_153[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_152[0][0]']
#                                 )
#
#  add_50 (Add)                   (None, 19, 19, 1024  0           ['add_49[0][0]',
#                                 )                                 'conv2d_154[0][0]']
#
#  activation_153 (Activation)    (None, 19, 19, 1024  0           ['add_50[0][0]']
#                                 )
#
#  conv2d_155 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_153[0][0]']
#
#  activation_154 (Activation)    (None, 19, 19, 256)  0           ['conv2d_155[0][0]']
#
#  zero_padding2d_51 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_154[0][0]']
#  2D)
#
#  conv2d_156 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_51[0][0]']
#
#  activation_155 (Activation)    (None, 19, 19, 256)  0           ['conv2d_156[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_155[0][0]']
#                                 )
#
#  add_51 (Add)                   (None, 19, 19, 1024  0           ['add_50[0][0]',
#                                 )                                 'conv2d_157[0][0]']
#
#  activation_156 (Activation)    (None, 19, 19, 1024  0           ['add_51[0][0]']
#                                 )
#
#  conv2d_158 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_156[0][0]']
#
#  activation_157 (Activation)    (None, 19, 19, 256)  0           ['conv2d_158[0][0]']
#
#  zero_padding2d_52 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_157[0][0]']
#  2D)
#
#  conv2d_159 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_52[0][0]']
#
#  activation_158 (Activation)    (None, 19, 19, 256)  0           ['conv2d_159[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_158[0][0]']
#                                 )
#
#  add_52 (Add)                   (None, 19, 19, 1024  0           ['add_51[0][0]',
#                                 )                                 'conv2d_160[0][0]']
#
#  activation_159 (Activation)    (None, 19, 19, 1024  0           ['add_52[0][0]']
#                                 )
#
#  conv2d_161 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_159[0][0]']
#
#  activation_160 (Activation)    (None, 19, 19, 256)  0           ['conv2d_161[0][0]']
#
#  zero_padding2d_53 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_160[0][0]']
#  2D)
#  conv2d_162 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_53[0][0]']
#
#  activation_161 (Activation)    (None, 19, 19, 256)  0           ['conv2d_162[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_161[0][0]']
#                                 )
#
#  add_53 (Add)                   (None, 19, 19, 1024  0           ['add_52[0][0]',
#                                 )                                 'conv2d_163[0][0]']
#
#  activation_162 (Activation)    (None, 19, 19, 1024  0           ['add_53[0][0]']
#                                 )
#
#  conv2d_164 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_162[0][0]']
#
#  activation_163 (Activation)    (None, 19, 19, 256)  0           ['conv2d_164[0][0]']
#
#  zero_padding2d_54 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_163[0][0]']
#  2D)
#
#  conv2d_165 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_54[0][0]']
#
#  activation_164 (Activation)    (None, 19, 19, 256)  0           ['conv2d_165[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_164[0][0]']
#                                 )
#
#  add_54 (Add)                   (None, 19, 19, 1024  0           ['add_53[0][0]',
#                                 )                                 'conv2d_166[0][0]']
#
#  activation_165 (Activation)    (None, 19, 19, 1024  0           ['add_54[0][0]']
#                                 )
#
#  conv2d_167 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_165[0][0]']
#
#  activation_166 (Activation)    (None, 19, 19, 256)  0           ['conv2d_167[0][0]']
#
#  zero_padding2d_55 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_166[0][0]']
#  2D)
#
#  conv2d_168 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_55[0][0]']
#
#  activation_167 (Activation)    (None, 19, 19, 256)  0           ['conv2d_168[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_167[0][0]']
#                                 )
#
#  add_55 (Add)                   (None, 19, 19, 1024  0           ['add_54[0][0]',
#                                 )                                 'conv2d_169[0][0]']
#
#  activation_168 (Activation)    (None, 19, 19, 1024  0           ['add_55[0][0]']
#                                 )
#
#  conv2d_170 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_168[0][0]']
#
#  activation_169 (Activation)    (None, 19, 19, 256)  0           ['conv2d_170[0][0]']
#
#  zero_padding2d_56 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_169[0][0]']
#  2D)
#
#  conv2d_171 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_56[0][0]']
#
#  activation_170 (Activation)    (None, 19, 19, 256)  0           ['conv2d_171[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_170[0][0]']
#                                 )
#
#  add_56 (Add)                   (None, 19, 19, 1024  0           ['add_55[0][0]',
#                                 )                                 'conv2d_172[0][0]']
#
#  activation_171 (Activation)    (None, 19, 19, 1024  0           ['add_56[0][0]']
#                                 )
#
#  conv2d_173 (Conv2D)            (None, 19, 19, 256)  262144      ['activation_171[0][0]']
#
#  activation_172 (Activation)    (None, 19, 19, 256)  0           ['conv2d_173[0][0]']
#
#  zero_padding2d_57 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_172[0][0]']
#  2D)
#
#  conv2d_174 (Conv2D)            (None, 19, 19, 256)  589824      ['zero_padding2d_57[0][0]']
#
#  activation_173 (Activation)    (None, 19, 19, 256)  0           ['conv2d_174[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 19, 19, 1024  263168      ['activation_173[0][0]']
#                                 )
#
#  add_57 (Add)                   (None, 19, 19, 1024  0           ['add_56[0][0]',
#                                 )                                 'conv2d_175[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1024)        0           ['add_57[0][0]']
#  2D)
#
#  fc1000 (Dense)                 (None, 361)          370025      ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 32,472,169
# Trainable params: 32,472,169
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callback1 = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, 
                                patience=3, verbose=0, mode='min'
                                 , restore_best_weights=True)
callback2 = tf.keras.callbacks.ModelCheckpoint('./models/model_kyu_v2_b64_f256_l100_cor_{epoch:02d}_{val_accuracy:.4f}.h5', 
                                            monitor='val_accuracy', 
                                            verbose=0, save_best_only=False, save_weights_only=False, 
                                            mode='max', save_freq="epoch")

# %%
# model = load_model('./models/model_kyu_f256_l88_mir_02_0.0035.h5')

# %%
history = model.fit(
    dataset,
    epochs = 500,
#     steps_per_epoch = train_steps,
    validation_data = dataset_valid,
#     validation_steps = val_steps,
    callbacks = [callback1, callback2]
)
# Out:
# Epoch 1/500
#      31/Unknown - 32s 303ms/step - loss: 5.9015 - accuracy: 0.0045
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 history = model.fit(
#       2     dataset,
#       3     epochs = 500,
#       4 #     steps_per_epoch = train_steps,
#       5     validation_data = dataset_valid,
#       6 #     validation_steps = val_steps,
#       7     callbacks = [callback1, callback2]
#       8 )
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
# model.save('./models/model_kyu_v2_b64_f256_l100_cor_5.h5')
